# %%
mean = [0, 0]
cov = [[1, 0], [0, 100]]  # diagonal covariance

import matplotlib.pyplot as plt
import numpy as np
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

print(np.random.multivariate_normal(mean, cov, 5000).shape)
print(np.random.multivariate_normal(mean, cov, 5000).T.shape)
print(x.mean(),x.std())
print(y.mean(),y.std())
# Out:
# (5000, 2)
# (2, 5000)
# 0.01019587105062037 1.0112461920829592
# -0.069271913492901 9.891842280490303

# %%
cov = np.array([[6, -3], [-3, 3.5]])
pts = np.random.multivariate_normal([0, 0], cov, size=800)

import matplotlib.pyplot as plt
import numpy as np
x, y = np.random.multivariate_normal(mean, cov, 5000).T
plt.plot(x, y, 'x')
plt.axis('equal')
plt.show()

print(np.random.multivariate_normal(mean, cov, 5000).shape)
print(np.random.multivariate_normal(mean, cov, 5000).T.shape)
print(x.mean(),x.std())
print(y.mean(),y.std())
# Out:
# (5000, 2)
# (2, 5000)
# 0.053284365993321946 2.3913786829735364
# -0.01838633465809566 1.8587811043131577

# %%
pts.mean(axis=0)
# Out:
# array([-0.08102306,  0.05596731])

# %%
np.cov(pts.T)
# Out:
# array([[ 6.04495148, -3.04959874],
#        [-3.04959874,  3.52024482]])

# %%
np.corrcoef(pts.T)[0, 1]
# Out:
# -0.6610888862554365

# %%
import matplotlib.pyplot as plt
plt.plot(pts[:, 0], pts[:, 1], '.', alpha=0.5)
plt.axis('equal')
plt.grid()
plt.show()
